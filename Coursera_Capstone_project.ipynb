# %% [markdown]
# # Notebook of the Coursera Capstone Project

# %% [markdown]
# ## 200523
# This is the first week of this course and I just started with GitHub, Repository and Git Bash.
# All of this is very exciting, looking forward of the next tasks. Good luck to all of us :)

# %%
# importing packages and libraries
import pandas as pd
import numpy as np

# %%
# get started!
print ('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
